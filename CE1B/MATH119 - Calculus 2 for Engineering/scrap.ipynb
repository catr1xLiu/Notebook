# %% [markdown]
# # Applications of Tangent Lines
#
# This file demonstrates different ways of finding the root of a function using tangent lines.

# %%
from math import cos, sin, e

from matplotlib import pyplot as plt
import numpy as np

def f(x):
    return e ** x - 2 * cos(x)
def df(x):
    return e ** x + 2 * sin(x)

## Use bisection method to find the root of f(x) = 0

MAX_ITER = 1000
TOL = 1e-5

x_span = np.linspace(0, 2, 100)


# First, we use the
