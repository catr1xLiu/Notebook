# %%
e0 = 8.854187817e-12

# %%
from numpy import pi
A = pi * (0.1)**2

for d in [0.005, 0.01, 0.015, 0.02, 0.025, 0.03]:
    print(d, e0 * A / d)
# Out:
# 0.005 5.5632502798782904e-11
# 0.01 2.7816251399391452e-11
# 0.015 1.8544167599594303e-11
# 0.02 1.3908125699695726e-11
# 0.025 1.112650055975658e-11
# 0.03 9.272083799797152e-12

# %%
distance = [0.005, 0.01, 0.015, 0.02, 0.025, 0.03]
surface_charge = [
    6.2319e-8,
    3.4143e-8,
    2.4659e-8,
    1.9917e-8,
    1.7028e-8,
    1.5124e-8
]

# %%
for i in range(6):
    Q = surface_charge[i]
    d = distance[i]
    C = Q / 1000
    print(d, Q, C)
# Out:
# 0.005 6.2319e-08 6.2319e-11
# 0.01 3.4143e-08 3.4143e-11
# 0.015 2.4659e-08 2.4659e-11
# 0.02 1.9917e-08 1.9916999999999998e-11
# 0.025 1.7028e-08 1.7027999999999997e-11
# 0.03 1.5124e-08 1.5124e-11

# %%
0.5 * 6.2319e-11 * (25)**2
# Out:
# 1.9474687500000002e-08

# %%
static = 37 # pF
measured = [95.3, 65.2, 51.3, 50.2, 46.4, 45.1, 44.2] # pF
measured_diel = [305.1, 80.5, 60.7, 56.7] #pF
measured_half_diel = [218.5, 76.3, 60.4, 57.5] #pF

diel_thickness = 2.78e-3
half_diel_thickness = 3.06e-3

capacitance_infinite_far = 34.5 # pF
